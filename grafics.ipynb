# %% [markdown]
# <a href="https://colab.research.google.com/github/Manolonava1602/Curso-Phyton-Tarea-1/blob/main/grafics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Impotamos las lbrerias necesarias
import numpy as np
import math as mt
import matplotlib.pyplot as plt
import pandas as pd
import requests
import os

# %%
# Datos Carbon Dots
path = f'/content/CqarbonDots.csv'
tabla1 = pd.read_csv(path, header=0)
path2 = f'/content/CarbonDotsAgua.csv'
tabla2 = pd.read_csv(path2, header=0)

# %%
tabla1
# Out:
#      Wavelength (nm)       Abs  ...  Wavelength (nm).6     Abs.6
# 0                800 -0.109015  ...                800 -0.175675
# 1                799 -0.108536  ...                799 -0.175596
# 2                798 -0.108165  ...                798 -0.175420
# 3                797 -0.108088  ...                797 -0.175330
# 4                796 -0.107670  ...                796 -0.175091
# ..               ...       ...  ...                ...       ...
# 596              204  2.746624  ...                204  4.933251
# 597              203  2.750209  ...                203  4.914031
# 598              202  2.750554  ...                202  4.895926
# 599              201  2.754740  ...                201  4.953134
# 600              200  2.755023  ...                200  4.919015
#
# [601 rows x 14 columns]

# %%
tabla2
# Out:
#       Wavelength (nm)    Abs  ...   Wavelength (nm).6   Abs.6
# 0                 800 -0.047  ...                 800   0.160
# 1                 799 -0.047  ...                 799   0.160
# 2                 798 -0.047  ...                 798   0.159
# 3                 797 -0.047  ...                 797   0.159
# 4                 796 -0.047  ...                 796   0.159
# ..                ...    ...  ...                 ...     ...
# 596               204 -1.094  ...                 204   4.299
# 597               203 -1.274  ...                 203   4.292
# 598               202 -1.494  ...                 202   4.293
# 599               201 -1.768  ...                 201   4.300
# 600               200 -2.109  ...                 200   4.306
#
# [601 rows x 14 columns]

# %%
x1 = tabla1.values[:,0]
y1 = tabla1.values[:,1]
y2 = tabla1.values[:,3]
y3 = tabla1.values[:,5]
y4 = tabla1.values[:,7]
y5 = tabla1.values[:,9]
y6 = tabla1.values[:,11]
y7 = tabla1.values[:,13]

# %%
a = tabla2.values[:,0]
b1 = tabla2.values[:,1]
b2 = tabla2.values[:,3]
b3 = tabla2.values[:,5]
b4 = tabla2.values[:,7]
b5 = tabla2.values[:,9]
b6 = tabla2.values[:,11]
b7 = tabla2.values[:,13]

# %%
plt.plot(x1, y5, '-',label="M1_22")
plt.plot(x1, y6, '-',label="M1_37")
plt.plot(x1, y1, '-',label="M2_22")
#plt.plot(x1, y2, '-', label="M1_47")
plt.plot(x1, y7, '-',label="M2_37")
plt.plot(x1, y3, '-', label="M2_47")
#plt.plot(x1, y4, '-',label="M2_67")
plt.legend()
plt.rcParams["figure.figsize"] = (15,10)
plt.xlabel("λ Longitud de onda (nm)", size = 16,)
plt.ylabel("Absorción(u.a)", size = 16)
plt.title("Espectros de absorción CqarbonDots", fontdict={'family': 'serif', 
                    'color' : 'darkblue',
                    'weight': 'bold',
                    'size': 18})

plt.grid(True)

# %%
#plt.plot(a, b1, '-',label="M2-67")
plt.plot(a, b5, '-',label="M1-22")
plt.plot(a, b6, '-',label="M1-37")
plt.plot(a, b4, '-',label="M2-22")
plt.plot(a, b3, '-',label="M2-42")
plt.plot(a, b2, '-',label="M2-47")
plt.legend()
plt.rcParams["figure.figsize"] = (15,10)
plt.xlabel("λ Longitud de onda (nm)", size = 16,)
plt.ylabel("Absorción(u.a)", size = 16)
plt.title("Espectros de absorción CarbonDotsAgua", fontdict={'family': 'serif', 
                    'color' : 'darkblue',
                    'weight': 'bold',
                    'size': 18})

plt.grid(True)
